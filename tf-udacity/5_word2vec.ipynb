# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
 
filename = 'text8.zip'
words = read_data(os.path.join('/home/mattw/data/other',filename))
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# print('data:', [reverse_dictionary[di] for di in data[:8]])
# for num_skips, skip_window in [(2, 1), (4, 2)]:
#     data_index = 0
#     batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
#     print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#     print('    batch:', [reverse_dictionary[bi] for bi in batch])
#     print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])

print('data:', [reverse_dictionary[di] for di in data[1000:1008]])
for num_skips, skip_window in [(4, 2), (2, 2)]:
    data_index = 1000
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['american', 'individualist', 'anarchism', 'benjamin', 'tucker', 'in', 'one', 'eight']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'anarchism', 'anarchism', 'anarchism', 'benjamin', 'benjamin', 'benjamin', 'benjamin']
#     labels: ['tucker', 'individualist', 'benjamin', 'american', 'tucker', 'in', 'anarchism', 'individualist']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['anarchism', 'anarchism', 'benjamin', 'benjamin', 'tucker', 'tucker', 'in', 'in']
#     labels: ['benjamin', 'individualist', 'in', 'tucker', 'anarchism', 'one', 'tucker', 'eight']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
random.seed(0)
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.734076
# Nearest to war: apt, celtic, redirected, dunes, exhortations, ideation, judo, canonic,
# Nearest to d: dale, gamespot, mei, perch, murdered, generalitat, lombok, canals,
# Nearest to but: somerville, distinguishable, straps, carries, barat, sayyid, leonhard, candy,
# Nearest to on: inferred, bakery, krajina, boxers, llamas, verge, inelastic, ultimate,
# Nearest to more: velar, infrequently, chilled, hears, woodcut, reinforce, dilation, endpin,
# Nearest to were: gunships, hymn, collusion, schematic, tariffs, smoothness, toned, instruments,
# Nearest to between: margraves, visit, fatty, amaziah, ingalls, acknowledgement, iron, farm,
# Nearest to his: bx, radians, deceased, sweetened, timeless, screened, grievance, ireland,
# Nearest to they: pogroms, diving, herbalists, bretagne, azo, litigation, collusion, animated,
# Nearest to new: quinlan, interpolated, daytona, hawker, tarleton, advertised, enclave, course,
# Nearest to use: incubus, pileser, faq, ak, momentary, nylon, lip, bis,
# Nearest to all: then, accurate, migration, viewing, alboin, supermarkets, neoliberal, procured,
# Nearest to from: broaden, alerting, attachment, capri, coleridge, eusebio, daoud, flips,
# Nearest to after: unwritten, egregious, toxicity, tonle, stargate, dass, conspired, vlaams,
# Nearest to up: capitalize, brink, stored, hitter, mahesh, impious, mujibur, scranton,
# Nearest to years: egbert, ethnological, nba, sahib, semifinals, repair, duns, diets,
# Average loss at step 2000: 4.585630
# Average loss at step 4000: 4.110824
# Average loss at step 6000: 4.036781
# Average loss at step 8000: 3.942657
# Average loss at step 10000: 3.943642
# Nearest to war: extend, exhortations, dunes, celtic, redirected, carnegie, apt, peltier,
# Nearest to d: b, murdered, gamespot, nephropathy, chesapeake, zedong, juries, generalitat,
# Nearest to but: distinguishable, yielded, carries, hyperlinks, barat, no, still, landmass,
# Nearest to on: inferred, from, at, abeda, of, bakery, unlimited, cathal,
# Nearest to more: endpin, velar, chilled, infrequently, drayton, issa, polynomial, extravagance,
# Nearest to were: are, was, injunctions, darius, impress, redrawing, tariffs, hymn,
# Nearest to between: zn, portal, farm, of, visit, inequalities, ingalls, unreachable,
# Nearest to his: their, the, s, chlorophyll, tragedy, radians, bologna, brenda,
# Nearest to they: he, pogroms, momentous, litigation, i, buccaneers, csicop, stray,
# Nearest to new: quinlan, advertised, tarleton, unmistakable, iec, dunfermline, conjecture, yastrzemski,
# Nearest to use: momentary, issues, yoshi, thought, hydrophilic, ferrand, faq, languages,
# Nearest to all: then, cleave, blume, common, subtree, procured, metz, crazed,
# Nearest to from: on, with, in, at, for, of, and, seahawks,
# Nearest to after: during, tonle, infants, conspired, heil, before, jussive, penetration,
# Nearest to up: capitalize, webern, hitter, tezuka, impious, rhodesia, brink, praeger,
# Nearest to years: egbert, rinsing, homeomorphism, ethnological, argentinean, diets, dalnet, legalised,
# Average loss at step 12000: 3.867339
# Average loss at step 14000: 3.794943
# Average loss at step 16000: 3.726543
# Average loss at step 18000: 3.803157
# Average loss at step 20000: 3.826008
# Nearest to war: dunes, celtic, stu, afford, deir, coed, exhortations, vandal,
# Nearest to d: b, chesapeake, paparazzi, nephropathy, juries, fined, recife, institutionalized,
# Nearest to but: which, not, there, they, and, it, still, locomotives,
# Nearest to on: inferred, with, from, and, at, abeda, vector, parallels,
# Nearest to more: extravagance, reproductive, humanism, boycotted, forcing, sexist, issa, polygamous,
# Nearest to were: are, had, was, have, requires, entirety, redrawing, jacobian,
# Nearest to between: ingalls, zn, portal, brighton, visit, inequalities, gallon, stanley,
# Nearest to his: their, her, its, the, s, chlorophyll, defies, sih,
# Nearest to they: he, we, it, but, there, yes, blocks, could,
# Nearest to new: tarleton, quinlan, advertised, conjecture, unmistakable, yastrzemski, londinium, administration,
# Nearest to use: issues, momentary, hydrophilic, yoshi, languages, nylon, finalised, thought,
# Nearest to all: then, several, those, blackwell, some, pinnacles, crazed, subtree,
# Nearest to from: and, with, at, in, on, into, to, cone,
# Nearest to after: during, before, later, braudel, infants, captain, when, heil,
# Nearest to up: back, batman, either, bowdoin, capitalize, post, running, tezuka,
# Nearest to years: argentinean, year, rinsing, turmeric, homeomorphism, diets, men, ethnological,
# Average loss at step 22000: 3.772098
# Average loss at step 24000: 3.809369
# Average loss at step 26000: 3.827050
# Average loss at step 28000: 3.763987
# Average loss at step 30000: 3.843764
# Nearest to war: redirected, diffie, movie, choreographed, crosses, celtic, fractal, dunes,
# Nearest to d: b, nephropathy, chesapeake, fined, bacharach, boeing, krone, recife,
# Nearest to but: still, there, which, however, than, not, that, macs,
# Nearest to on: from, in, eugen, dor, inferred, at, yy, or,
# Nearest to more: less, rather, extravagance, endpin, boycotted, sexist, velar, hoddle,
# Nearest to were: are, was, had, have, requires, redrawing, being, many,
# Nearest to between: ingalls, with, portal, from, aafc, zn, evaporated, on,
# Nearest to his: their, her, its, s, chlorophyll, our, roundhouse, sih,
# Nearest to they: we, there, these, he, it, superjanet, pang, not,
# Nearest to new: advertised, citations, tarleton, conjecture, yastrzemski, stimulated, quinlan, southerner,
# Nearest to use: hydrophilic, finalised, momentary, issues, yoshi, brahms, dynamics, subculture,
# Nearest to all: some, many, several, subtree, those, different, negotiated, these,
# Nearest to from: into, on, in, and, between, variance, cone, through,
# Nearest to after: before, during, over, later, when, montezuma, had, windmill,
# Nearest to up: back, bowdoin, capitalize, batman, hitter, fossilized, strassman, emilio,
# Nearest to years: year, argentinean, rinsing, homeomorphism, days, alliance, synthesizing, turmeric,
# Average loss at step 32000: 3.788012
# Average loss at step 34000: 3.806899
# Average loss at step 36000: 3.617718
# Average loss at step 38000: 3.805837
# Average loss at step 40000: 3.728677
# Nearest to war: during, diffie, lubrication, ii, choreographed, coed, world, generalship,
# Nearest to d: b, boosting, bacharach, c, chesapeake, recife, fined, nephropathy,
# Nearest to but: however, there, they, only, not, that, when, although,
# Nearest to on: upon, suevi, monsignor, in, cathal, papyrus, kapitan, with,
# Nearest to more: less, rather, extravagance, most, sco, wayside, very, than,
# Nearest to were: are, was, have, being, be, had, their, relocation,
# Nearest to between: with, ingalls, from, gallon, goi, within, aware, visit,
# Nearest to his: her, their, its, s, the, our, chlorophyll, him,
# Nearest to they: we, these, there, not, but, he, it, usually,
# Nearest to new: predestination, discordianism, londinium, advertised, ripken, deterioration, rider, stimulated,
# Nearest to use: hydrophilic, finalised, yoshi, issues, marquis, authority, companionship, distilled,
# Nearest to all: many, these, some, several, those, different, their, subtree,
# Nearest to from: in, with, through, instinctively, into, between, of, over,
# Nearest to after: before, during, when, jagie, montezuma, over, later, for,
# Nearest to up: back, him, bowdoin, strassman, emilio, them, cno, batman,
# Nearest to years: year, days, argentinean, rinsing, alliance, homeomorphism, turmeric, synthesizing,
# Average loss at step 42000: 3.775578
# Average loss at step 44000: 3.768970
# Average loss at step 46000: 3.741955
# Average loss at step 48000: 3.702274
# Average loss at step 50000: 3.723990
# Nearest to war: during, championship, ii, diffie, carnegie, coed, lubrication, world,
# Nearest to d: b, c, f, j, UNK, r, boosting, fined,
# Nearest to but: however, and, though, while, than, who, he, when,
# Nearest to on: at, in, upon, papyrus, vector, inferred, ohm, platonic,
# Nearest to more: less, rather, extravagance, most, wayside, very, other, than,
# Nearest to were: are, was, being, had, been, be, rationalized, remembering,
# Nearest to between: with, ingalls, into, within, in, crematoria, from, aafc,
# Nearest to his: their, her, its, s, the, our, sih, chlorophyll,
# Nearest to they: we, there, he, not, others, yes, these, but,
# Nearest to new: advertised, predestination, douglas, reproduced, ong, agonists, portraiture, amylase,
# Nearest to use: hydrophilic, finalised, companionship, favorites, marquis, yoshi, participle, dynamics,
# Nearest to all: many, some, these, each, subtree, several, myriad, pairing,
# Nearest to from: through, into, with, of, instinctively, stump, in, and,
# Nearest to after: before, during, when, for, through, over, montezuma, of,
# Nearest to up: back, them, down, strassman, off, emilio, bowdoin, batman,
# Nearest to years: year, days, argentinean, million, decades, alliance, months, gasp,
# Average loss at step 52000: 3.767405
# Average loss at step 54000: 3.769996
# Average loss at step 56000: 3.738772
# Average loss at step 58000: 3.727872
# Average loss at step 60000: 3.616798
# Nearest to war: diffie, during, ii, championship, lubrication, casings, generalship, coed,
# Nearest to d: b, c, j, f, bacharach, boosting, r, fined,
# Nearest to but: however, although, than, though, which, it, when, because,
# Nearest to on: in, upon, through, premillennialism, from, consulship, cuttlefish, inferred,
# Nearest to more: less, rather, extravagance, velar, most, higher, sco, mute,
# Nearest to were: are, was, have, had, being, is, be, subterranean,
# Nearest to between: with, into, from, ingalls, over, husayn, within, industrial,
# Nearest to his: her, their, its, him, our, the, sih, roundhouse,
# Nearest to they: we, there, he, these, others, you, not, it,
# Nearest to new: predestination, rider, ong, usa, portraiture, heavyweight, cajun, evolutionary,
# Nearest to use: hydrophilic, yoshi, finalised, slack, marijuana, restrictions, minaret, infamy,
# Nearest to all: some, many, these, each, other, various, those, metz,
# Nearest to from: in, into, through, kv, dignity, between, or, on,
# Nearest to after: before, during, when, of, over, for, following, through,
# Nearest to up: back, down, them, out, strassman, freshwater, off, emilio,
# Nearest to years: year, days, argentinean, decades, million, months, gasp, rinsing,
# Average loss at step 62000: 3.617972
# Average loss at step 64000: 3.746803
# Average loss at step 66000: 3.728421
# Average loss at step 68000: 3.706034
# Average loss at step 70000: 3.715728
# Nearest to war: diffie, ii, championship, world, coed, during, period, lubrication,
# Nearest to d: b, j, c, r, boosting, v, bacharach, n,
# Nearest to but: however, than, only, did, when, not, because, they,
# Nearest to on: upon, through, eugen, between, impressive, kapitan, inferred, autonomist,
# Nearest to more: less, rather, most, even, very, extravagance, greater, wayside,
# Nearest to were: are, was, had, have, being, been, became, hoffman,
# Nearest to between: with, ingalls, within, into, on, aml, through, polemic,
# Nearest to his: her, their, its, the, s, our, chlorophyll, knees,
# Nearest to they: we, you, there, not, premieres, but, these, he,
# Nearest to new: rider, york, evolutionary, portraiture, tel, toby, conjectural, ong,
# Nearest to use: slack, marquis, dynamics, begining, hydrophilic, marijuana, finalised, minaret,
# Nearest to all: some, many, these, those, any, both, rejuvenation, each,
# Nearest to from: through, into, in, objected, peacekeepers, enhancement, auguste, between,
# Nearest to after: before, during, when, had, he, until, later, over,
# Nearest to up: back, them, out, down, off, strassman, swearing, him,
# Nearest to years: days, year, months, decades, million, argentinean, turmeric, times,
# Average loss at step 72000: 3.692590
# Average loss at step 74000: 3.653316
# Average loss at step 76000: 3.681988
# Average loss at step 78000: 3.731703
# Average loss at step 80000: 3.749350
# Nearest to war: diffie, ii, during, championship, world, softly, kulak, period,
# Nearest to d: b, c, j, r, p, boosting, f, n,
# Nearest to but: however, although, while, because, than, and, which, though,
# Nearest to on: through, in, upon, and, from, impressive, angelina, premillennialism,
# Nearest to more: less, rather, most, very, extravagance, greater, wayside, than,
# Nearest to were: are, was, had, being, is, be, been, blacks,
# Nearest to between: within, with, ingalls, beanstalk, over, into, interjection, aml,
# Nearest to his: her, their, its, our, him, weill, knees, my,
# Nearest to they: we, he, it, there, you, these, premieres, not,
# Nearest to new: channels, predestination, portraiture, york, battering, ripken, usa, agonists,
# Nearest to use: slack, marquis, hydrophilic, finalised, dynamics, mik, armchair, types,
# Nearest to all: many, some, various, these, several, those, any, each,
# Nearest to from: through, into, by, on, and, during, instinctively, before,
# Nearest to after: before, during, when, without, following, over, through, until,
# Nearest to up: out, down, them, back, off, strassman, him, swearing,
# Nearest to years: days, months, year, decades, argentinean, times, million, terminates,
# Average loss at step 82000: 3.750142
# Average loss at step 84000: 3.732116
# Average loss at step 86000: 3.709449
# Average loss at step 88000: 3.720996
# Average loss at step 90000: 3.688363
# Nearest to war: diffie, during, championship, ii, world, era, softly, coed,
# Nearest to d: b, c, j, v, n, p, r, f,
# Nearest to but: however, while, although, because, though, that, than, which,
# Nearest to on: upon, in, through, inferred, nightlife, dor, bette, cathal,
# Nearest to more: less, rather, most, very, extravagance, wayside, better, almagro,
# Nearest to were: are, was, being, had, have, is, lilian, rationalized,
# Nearest to between: with, within, ingalls, beanstalk, into, salut, warship, superimposed,
# Nearest to his: her, their, its, them, him, our, my, died,
# Nearest to they: he, we, you, these, there, she, it, who,
# Nearest to new: york, usa, channels, offices, pennsylvania, major, conjectural, fuego,
# Nearest to use: slack, negotiate, armchair, minaret, addition, rambla, dynamics, finalised,
# Nearest to all: many, several, various, any, some, these, same, each,
# Nearest to from: through, into, in, embodies, stump, eradicated, including, kv,
# Nearest to after: before, during, when, over, until, following, husbands, later,
# Nearest to up: out, off, down, back, them, strassman, him, together,
# Nearest to years: days, months, decades, year, million, minutes, argentinean, times,
# Average loss at step 92000: 3.654795
# Average loss at step 94000: 3.689660
# Average loss at step 96000: 3.614643
# Average loss at step 98000: 3.703831
# Average loss at step 100000: 3.678662
# Nearest to war: diffie, ii, championship, during, world, era, generalship, coed,
# Nearest to d: b, v, fined, benjamin, arif, c, entheogens, kilojoules,
# Nearest to but: although, however, because, while, and, though, which, hyperlinks,
# Nearest to on: upon, in, monsignor, cathal, debating, autonomist, impressive, at,
# Nearest to more: less, rather, most, very, better, greater, extravagance, much,
# Nearest to were: are, was, being, blacks, hoffman, be, lilian, many,
# Nearest to between: within, ingalls, with, over, beanstalk, superimposed, salut, aml,
# Nearest to his: her, their, its, the, our, s, him, my,
# Nearest to they: we, you, there, he, could, these, mobilized, malted,
# Nearest to new: york, deterioration, channels, predestination, battering, ripken, usa, consultative,
# Nearest to use: addition, armchair, tiglath, slack, refer, rambla, retrieving, negotiate,
# Nearest to all: many, these, several, various, norwood, some, any, metz,
# Nearest to from: through, into, at, mega, embodies, in, vpn, instinctively,
# Nearest to after: before, during, when, later, following, without, over, arbuthnot,
# Nearest to up: back, them, off, out, down, strassman, him, thanked,
# Nearest to years: days, months, year, decades, times, million, minutes, turmeric,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# for a given word, get all words within a window around it

data_index = 0

def generate_batch_CBOW(batch_size, word_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2*word_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * word_window + 1
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = word_window  # target label at the center of the buffer
    labels[i, 0] = buffer[target]
    for j in range(word_window):
      batch[i, j] = buffer[target - word_window + j]
      batch[i, word_window + j] = buffer[target + 1 + j]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[990:1008]])
data_index = 1000
batch_size = 8
word_window = 2
batch, labels = generate_batch_CBOW(batch_size=batch_size, word_window=word_window)
print('\nwith word_window = %d' % word_window)
for i in range(batch_size):
  print('    labels:', reverse_dictionary[labels[i,0]])
  print('    batch:', [reverse_dictionary[bi] for bi in batch[i,:]])
# Out:
# data: ['UNK', 'inclined', 'anarchists', 'although', 'interpretations', 'of', 'his', 'thought', 'are', 'diverse', 'american', 'individualist', 'anarchism', 'benjamin', 'tucker', 'in', 'one', 'eight']
#
# with word_window = 2
#     labels: anarchism
#     batch: ['american', 'individualist', 'benjamin', 'tucker']
#     labels: benjamin
#     batch: ['individualist', 'anarchism', 'tucker', 'in']
#     labels: tucker
#     batch: ['anarchism', 'benjamin', 'in', 'one']
#     labels: in
#     batch: ['benjamin', 'tucker', 'one', 'eight']
#     labels: one
#     batch: ['tucker', 'in', 'eight', 'two']
#     labels: eight
#     batch: ['in', 'one', 'two', 'five']
#     labels: two
#     batch: ['one', 'eight', 'five', 'josiah']
#     labels: five
#     batch: ['eight', 'two', 'josiah', 'warren']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
word_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
random.seed(0)
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * word_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # add embedding vectors for each training instance
  embed_sum = tf.reduce_sum(embed, reduction_indices=1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed_sum,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, word_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.416016
# Nearest to war: akihabara, rochelle, blocker, faroese, inciting, achieves, note, roasting,
# Nearest to d: retaliate, calories, maximilian, prometheus, wretched, cosmetics, hearne, arsenic,
# Nearest to but: leitch, marvel, fugazi, masovia, islas, housemate, exogenous, ginette,
# Nearest to on: littoral, hopefully, watermelon, nite, reactor, shooters, varsity, transmigration,
# Nearest to more: conductors, poison, graf, marlow, runnymede, apocalypse, borrowing, boopsie,
# Nearest to were: wonders, save, foxy, vitally, conducive, slings, guppy, zinn,
# Nearest to between: impedes, elsewhere, charles, donate, hardwoods, phrased, unneeded, relegation,
# Nearest to his: amalgamation, addison, rout, galton, fun, yousef, numerology, airforce,
# Nearest to they: generating, hazard, zout, hyperinflation, inversion, anzac, elite, inter,
# Nearest to new: cbt, albigensian, fontsize, eca, transfection, exe, libro, recreations,
# Nearest to use: fare, scans, standout, tails, adele, spelling, convenes, contaminants,
# Nearest to all: modifications, laban, bloodlines, boulez, mechanization, prakrit, atreides, moorehead,
# Nearest to from: faltered, essayist, definitional, jumbled, marys, sensible, agassiz, touched,
# Nearest to after: tire, these, nichols, sidelined, bookmarks, hemi, detonates, whipple,
# Nearest to up: multipart, uncovering, buoyancy, blaxploitation, paraphyletic, analogue, moritz, wichita,
# Nearest to years: doubly, insurgents, mindaugas, endings, archer, gable, upwelling, metamorphism,
# Average loss at step 2000: 4.148299
# Average loss at step 4000: 3.517888
# Average loss at step 6000: 3.427835
# Average loss at step 8000: 3.372222
# Average loss at step 10000: 3.271196
# Nearest to war: saraswati, vico, achieves, maccabean, inciting, earnhardt, rochelle, referenda,
# Nearest to d: retaliate, wretched, maniac, bakr, theoretic, prometheus, calories, cosmogony,
# Nearest to but: marquee, revolutionize, mustang, nde, though, pakistani, kammu, however,
# Nearest to on: in, protested, upon, barrymore, at, fonni, arcane, energized,
# Nearest to more: boopsie, less, most, playground, ordinarily, hbo, very, borrowing,
# Nearest to were: are, was, have, had, include, been, stopped, bock,
# Nearest to between: with, hardwoods, when, poz, powell, in, mappings, polish,
# Nearest to his: their, her, its, s, the, whitehead, airforce, guevara,
# Nearest to they: he, there, we, i, roslin, she, you, it,
# Nearest to new: fontsize, humphreys, lewisham, pronoun, unscathed, otranto, deficiency, applets,
# Nearest to use: malaya, medusa, unpredictability, standout, sadism, bernini, dvb, scans,
# Nearest to all: many, keeling, some, me, gilles, both, any, several,
# Nearest to from: in, logistic, capoeira, bakker, into, quorum, aurangabad, duress,
# Nearest to after: nichols, dup, equip, continuations, when, aunt, trisomy, partisan,
# Nearest to up: multipart, drenthe, uncovering, bedrooms, buoyancy, paraphyletic, army, zener,
# Nearest to years: days, doubly, jedi, johnston, gish, chorale, welt, gable,
# Average loss at step 12000: 3.119121
# Average loss at step 14000: 3.148018
# Average loss at step 16000: 3.107589
# Average loss at step 18000: 3.115078
# Average loss at step 20000: 3.063928
# Nearest to war: cassava, earnhardt, strata, maccabean, am, rochelle, nj, spire,
# Nearest to d: b, arthur, boast, theoretic, retaliate, bakr, arsenic, nicks,
# Nearest to but: however, and, though, than, id, legalizing, baltic, monaghan,
# Nearest to on: upon, in, during, under, through, fonni, julie, block,
# Nearest to more: less, most, very, highlights, playground, boopsie, faster, occuring,
# Nearest to were: are, have, had, was, include, those, upu, is,
# Nearest to between: with, lanka, hardwoods, powell, mappings, atrial, swarm, filed,
# Nearest to his: their, her, its, my, our, the, s, airforce,
# Nearest to they: he, we, there, you, she, it, who, quickly,
# Nearest to new: great, humphreys, applets, paths, referential, lower, hydrocarbon, technetium,
# Nearest to use: malaya, repackaged, sadism, dvb, unpredictability, standout, convenes, censured,
# Nearest to all: both, some, these, many, me, several, cater, inadequately,
# Nearest to from: in, into, quorum, under, during, logistic, towards, duress,
# Nearest to after: before, during, when, nichols, continuations, dup, without, although,
# Nearest to up: him, drenthe, bedrooms, uncovering, multipart, zener, off, catcher,
# Nearest to years: days, year, doubly, gish, times, months, jedi, interoperability,
# Average loss at step 22000: 2.952578
# Average loss at step 24000: 3.076431
# Average loss at step 26000: 3.072327
# Average loss at step 28000: 2.946084
# Average loss at step 30000: 2.967669
# Nearest to war: earnhardt, ebcdic, referenda, maccabean, looping, nj, spire, rochelle,
# Nearest to d: b, arthur, boast, retaliate, arsenic, gerard, kornbluth, theoretic,
# Nearest to but: however, adverts, although, dinah, while, though, recognizing, invoked,
# Nearest to on: upon, through, about, consulates, around, ap, grieving, analytical,
# Nearest to more: less, most, very, highlights, faster, playground, greater, boopsie,
# Nearest to were: are, include, have, be, had, was, those, been,
# Nearest to between: with, lanka, poz, mappings, grands, in, narn, maoism,
# Nearest to his: her, their, my, its, your, our, the, turbofan,
# Nearest to they: we, he, there, you, she, i, it, these,
# Nearest to new: applets, centre, referential, great, emigrants, doorways, lower, lewisham,
# Nearest to use: desegregation, sadism, skaro, help, dvb, turn, alias, rationals,
# Nearest to all: both, many, some, any, several, various, every, me,
# Nearest to from: through, into, drying, moncada, logistic, across, quorum, streamlining,
# Nearest to after: before, during, when, without, while, at, for, despite,
# Nearest to up: off, out, back, down, him, bedrooms, drenthe, uncovering,
# Nearest to years: days, year, times, months, interoperability, weeks, decades, centuries,
# Average loss at step 32000: 2.947315
# Average loss at step 34000: 2.956697
# Average loss at step 36000: 2.966749
# Average loss at step 38000: 2.848559
# Average loss at step 40000: 2.945420
# Nearest to war: earnhardt, spire, rochelle, maccabean, gurps, strata, referenda, verity,
# Nearest to d: b, boast, arthur, retaliate, outputting, gerard, rapp, UNK,
# Nearest to but: however, although, though, dinah, included, while, typically, id,
# Nearest to on: upon, through, in, under, whitewater, during, within, vfr,
# Nearest to more: less, most, very, faster, larger, playground, quite, ministries,
# Nearest to were: are, have, include, was, being, be, had, those,
# Nearest to between: among, with, hardwoods, in, poz, when, kazan, across,
# Nearest to his: her, their, my, its, your, our, the, backups,
# Nearest to they: we, you, there, he, she, i, it, not,
# Nearest to new: eca, emigrants, walser, humphreys, technetium, applets, following, roman,
# Nearest to use: wake, greats, hutterite, because, decorate, ability, unproduced, filament,
# Nearest to all: both, every, some, various, keeling, many, several, riots,
# Nearest to from: through, into, quorum, during, after, stile, across, in,
# Nearest to after: before, during, when, without, for, delicacy, ammonius, within,
# Nearest to up: off, back, out, down, him, them, bedrooms, zener,
# Nearest to years: days, year, centuries, months, weeks, decades, interoperability, times,
# Average loss at step 42000: 2.879599
# Average loss at step 44000: 2.854625
# Average loss at step 46000: 2.398635
# Average loss at step 48000: 2.631142
# Average loss at step 50000: 2.779486
# Nearest to war: earnhardt, aggression, am, spire, maccabean, wars, ungodly, astatine,
# Nearest to d: b, c, theoretic, ireann, rapp, arthur, kornbluth, affinities,
# Nearest to but: however, though, and, although, while, or, lovecraftian, bootlegs,
# Nearest to on: upon, about, in, under, consulates, outfield, through, during,
# Nearest to more: less, most, rather, very, faster, greater, larger, quite,
# Nearest to were: are, include, was, have, had, those, bloomfield, while,
# Nearest to between: with, poz, hardwoods, within, mappings, among, lanka, narn,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to they: we, he, you, she, there, who, it, i,
# Nearest to new: lament, handling, walser, maquis, humphreys, eca, lewisham, nemesis,
# Nearest to use: end, turn, ability, house, paralysis, wake, because, hutterite,
# Nearest to all: both, many, some, these, various, keeling, those, several,
# Nearest to from: into, through, towards, quorum, after, in, during, drying,
# Nearest to after: before, during, when, without, sanitarium, while, advocating, ammonius,
# Nearest to up: off, out, down, back, him, them, bedrooms, together,
# Nearest to years: days, months, year, decades, weeks, centuries, minutes, hours,
# Average loss at step 52000: 2.768511
# Average loss at step 54000: 2.893215
# Average loss at step 56000: 2.851377
# Average loss at step 58000: 2.670882
# Average loss at step 60000: 2.843357
# Nearest to war: wars, earnhardt, rochelle, spire, am, aggression, ungodly, sandalwood,
# Nearest to d: b, ireann, theoretic, cowboys, outputting, rapp, cain, bakr,
# Nearest to but: however, although, though, and, while, than, sault, lovecraftian,
# Nearest to on: upon, in, through, within, consulates, during, from, cpk,
# Nearest to more: less, most, very, larger, faster, quite, rather, smaller,
# Nearest to were: are, was, include, have, those, be, including, persuasive,
# Nearest to between: with, within, poz, among, lanka, across, hardwoods, through,
# Nearest to his: her, their, my, your, its, our, the, whose,
# Nearest to they: we, he, there, she, you, it, who, these,
# Nearest to new: different, handling, return, jubilees, lament, fourth, walser, maquis,
# Nearest to use: sense, paralysis, fundamentals, appear, portions, end, necessity, maxime,
# Nearest to all: both, some, various, many, keeling, every, these, riots,
# Nearest to from: through, quorum, across, of, into, towards, drying, by,
# Nearest to after: before, during, without, when, despite, ammonius, sanitarium, while,
# Nearest to up: off, out, back, down, together, bedrooms, them, him,
# Nearest to years: days, months, year, weeks, decades, centuries, minutes, hours,
# Average loss at step 62000: 2.850244
# Average loss at step 64000: 2.843159
# Average loss at step 66000: 2.594691
# Average loss at step 68000: 2.698695
# Average loss at step 70000: 2.661773
# Nearest to war: wars, earnhardt, spire, aggression, am, sandalwood, maccabean, boer,
# Nearest to d: b, cowboys, milan, theoretic, switzer, aediles, animations, rockers,
# Nearest to but: however, although, though, and, which, despite, while, saab,
# Nearest to on: upon, in, during, around, within, reds, until, outfield,
# Nearest to more: less, most, quite, greater, faster, rather, longer, increasingly,
# Nearest to were: are, was, have, include, be, require, had, those,
# Nearest to between: with, within, among, across, wheels, unloaded, hardwoods, sorrows,
# Nearest to his: her, their, your, my, its, the, our, goldeneye,
# Nearest to they: we, you, she, he, there, it, i, these,
# Nearest to new: different, stretched, humphreys, referential, maquis, faroe, malinowski, technetium,
# Nearest to use: consist, paralysis, appear, tradesmen, call, support, start, hold,
# Nearest to all: both, many, various, every, several, these, some, freshness,
# Nearest to from: through, under, across, into, drying, during, moncada, quorum,
# Nearest to after: before, during, despite, when, without, while, for, at,
# Nearest to up: off, back, down, out, him, bedrooms, them, away,
# Nearest to years: days, decades, months, year, weeks, centuries, hours, minutes,
# Average loss at step 72000: 2.825203
# Average loss at step 74000: 2.693119
# Average loss at step 76000: 2.802112
# Average loss at step 78000: 2.798917
# Average loss at step 80000: 2.752905
# Nearest to war: wars, aggression, earnhardt, prevenient, battle, boer, sandalwood, maccabean,
# Nearest to d: b, ireann, rapp, cowboys, georgi, aediles, theoretic, possessive,
# Nearest to but: however, though, although, and, katha, exceed, see, mello,
# Nearest to on: upon, within, through, around, analytical, during, outfield, reds,
# Nearest to more: less, quite, greater, most, rather, very, faster, longer,
# Nearest to were: are, was, include, have, had, those, including, been,
# Nearest to between: with, within, among, across, over, hardwoods, wheels, maoism,
# Nearest to his: her, their, your, its, my, our, the, whose,
# Nearest to they: we, he, you, there, she, i, it, these,
# Nearest to new: different, humphreys, lament, walser, fictional, screenshots, technetium, kernels,
# Nearest to use: using, tradesmen, ability, watering, consist, agade, sense, fundamentals,
# Nearest to all: both, various, many, some, these, those, several, each,
# Nearest to from: into, through, in, during, across, drying, ecotourism, autodidacts,
# Nearest to after: before, when, during, without, while, despite, although, following,
# Nearest to up: off, down, back, out, him, them, together, zener,
# Nearest to years: days, decades, months, year, weeks, hours, minutes, centuries,
# Average loss at step 82000: 2.685495
# Average loss at step 84000: 2.772811
# Average loss at step 86000: 2.613984
# Average loss at step 88000: 2.733290
# Average loss at step 90000: 2.704772
# Nearest to war: wars, aggression, real, earnhardt, am, battle, e, ungodly,
# Nearest to d: b, theoretic, rapp, ireann, cowboys, helix, poke, glossy,
# Nearest to but: however, although, though, and, which, see, bootlegs, while,
# Nearest to on: upon, in, within, through, analytical, consulates, outfield, during,
# Nearest to more: less, most, quite, greater, very, rather, faster, increasingly,
# Nearest to were: are, was, include, have, had, those, been, being,
# Nearest to between: within, with, among, across, against, wheels, maoism, hardwoods,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to they: we, you, there, he, she, it, these, i,
# Nearest to new: different, screenshots, technetium, faroe, fictional, humphreys, madhuri, walser,
# Nearest to use: ability, form, usage, sense, consist, tradesmen, limit, feature,
# Nearest to all: both, various, many, any, several, those, some, examinations,
# Nearest to from: into, logistic, through, before, drying, faithfulness, ment, quorum,
# Nearest to after: before, during, despite, when, without, while, for, afterwards,
# Nearest to up: off, down, back, out, him, them, bedrooms, uncovering,
# Nearest to years: days, decades, months, weeks, hours, minutes, centuries, year,
# Average loss at step 92000: 2.756234
# Average loss at step 94000: 2.752767
# Average loss at step 96000: 2.616802
# Average loss at step 98000: 2.747634
# Average loss at step 100000: 2.737052
# Nearest to war: wars, am, earnhardt, battle, aggression, adolfo, ungodly, series,
# Nearest to d: b, cowboys, rapp, coma, r, byrnes, ireann, boast,
# Nearest to but: however, although, though, and, while, despite, see, that,
# Nearest to on: upon, in, within, around, near, through, under, hatti,
# Nearest to more: less, most, quite, greater, very, rather, faster, highly,
# Nearest to were: are, have, was, been, those, include, be, had,
# Nearest to between: with, among, within, across, wheels, hardwoods, along, sorrows,
# Nearest to his: her, their, my, its, your, our, turbofan, whose,
# Nearest to they: we, he, you, there, she, i, it, these,
# Nearest to new: walser, different, recent, modern, faroe, technetium, screenshots, pagan,
# Nearest to use: limit, ability, usage, history, feature, sense, consist, course,
# Nearest to all: both, every, various, any, many, several, failing, each,
# Nearest to from: through, into, across, drying, ecotourism, comprising, streamlining, moncada,
# Nearest to after: before, during, without, despite, when, afterwards, following, while,
# Nearest to up: off, down, out, back, him, them, bedrooms, zener,
# Nearest to years: days, decades, months, weeks, minutes, hours, centuries, year,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
